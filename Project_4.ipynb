# %%
from pathlib import Path
import pandas as pd

# %%
# Read College_qbr csv
college_qbr_path = Path(r"C:\Users\hsyuk\OneDrive\Desktop\GW Bootcamp\Section 5 - Advanced Topics (18-24)\Project_4\Resources\college_qbr.csv")
college_qbr_df = pd.read_csv(college_qbr_path)
college_qbr_df
# Out:
#       season                                  guid     player_name   age  \
# 0       2004      b518c8332d8a45a6348f93e245d3aca8   Stefan LeFors  23.0
# 1       2004      5cb521dc4af2c7598251a369ffaf4c72      Alex Smith  36.0
# 2       2004      00be888b38b5e26fc4b4d18aca23e7b7     Jason White  24.0
# 3       2004      c794b72ed323e01f9bc984d5a48003ff  Jason Campbell  33.0
# 4       2004      a7277955dbfa7b56283b8246d4ba987c      Matt Jones  32.0
# ...      ...                                   ...             ...   ...
# 2044    2020  aaab6e81-bfa6-3ceb-bb91-e9e31a23552b   Jalon Daniels   NaN
# 2045    2020      766f0f34ffbd728a3efc3ae242de0c31       Trae Hall   NaN
# 2046    2020      e141b9fb46c5e50b9280d68de67fa9e5     Zach Gibson   NaN
# 2047    2020      9c39c3e1391ce5c59041ffb108bfbc6b   Matt McDonald   NaN
# 2048    2020  ca55a29b-4467-38d5-b372-a1021672dd3a   Jonah Johnson   NaN
#
#       total_qbr  points_added  qb_plays  total_epa  pass   run  exp_sack  \
# 0          86.3          68.3       351       66.8  66.5   2.8      -3.7
# 1          84.5          75.8       480       73.4  63.5  16.0      -7.3
# 2          84.1          56.6       454       61.2  70.9  -6.2      -5.4
# 3          83.3          41.5       373       48.4  56.9  -3.9      -6.5
# 4          81.7          35.9       383       43.6  24.4  27.5      -7.1
# ...         ...           ...       ...        ...   ...   ...       ...
# 2044       23.8         -40.0       247      -17.0  -5.1  -1.1     -11.8
# 2045       21.3         -13.0       150       -4.7  -2.4   4.0      -5.3
# 2046       20.0         -17.7       195       -5.9   7.2  -4.8      -9.0
# 2047       17.8         -17.0       165       -5.7  -0.2  -0.4      -4.9
# 2048        3.6          -5.9        88       -1.2   0.9  -0.2      -1.7
#
#       penalty  raw_qbr  sack
# 0         1.6     88.3  -3.7
# 1         1.2     83.8  -7.3
# 2         2.7     78.5  -6.1
# 3         2.0     76.1  -6.7
# 4        -0.7     72.6  -7.7
# ...       ...      ...   ...
# 2044      1.1     15.7 -11.8
# 2045      0.2     28.9  -6.5
# 2046      0.8     28.0  -9.0
# 2047     -0.2     25.5  -4.9
# 2048     -0.1     33.3  -1.7
#
# [2049 rows x 14 columns]

# %%
college_qbr_df.dropna()
# Out:
#       season                              guid     player_name   age  \
# 0       2004  b518c8332d8a45a6348f93e245d3aca8   Stefan LeFors  23.0
# 1       2004  5cb521dc4af2c7598251a369ffaf4c72      Alex Smith  36.0
# 2       2004  00be888b38b5e26fc4b4d18aca23e7b7     Jason White  24.0
# 3       2004  c794b72ed323e01f9bc984d5a48003ff  Jason Campbell  33.0
# 4       2004  a7277955dbfa7b56283b8246d4ba987c      Matt Jones  32.0
# ...      ...                               ...             ...   ...
# 1851    2019  22c8fe738dcaea7c8ddd9e1f1b8fccbf     Jacob Eason  23.0
# 1865    2019  778de00a350eea5de64ffd0070c4384f    Kelly Bryant  23.0
# 1882    2019  2d98566410ac3cb32955c5f22fc9cefe    James Morgan  24.0
# 1889    2019  f19ea9a5ca4d79b93e49543e438cd336     Jordan Love  22.0
# 1925    2020  7e9fbd60951e2d9a8d8cb3f1ab6c4a4d   Justin Fields  22.0
#
#       total_qbr  points_added  qb_plays  total_epa  pass   run  exp_sack  \
# 0          86.3          68.3       351       66.8  66.5   2.8      -3.7
# 1          84.5          75.8       480       73.4  63.5  16.0      -7.3
# 2          84.1          56.6       454       61.2  70.9  -6.2      -5.4
# 3          83.3          41.5       373       48.4  56.9  -3.9      -6.5
# 4          81.7          35.9       383       43.6  24.4  27.5      -7.1
# ...         ...           ...       ...        ...   ...   ...       ...
# 1851       65.9          24.6       497       40.4  48.6   2.6     -13.0
# 1865       60.2           3.9       430       20.1  25.8   4.8     -11.7
# 1882       53.7          18.6       405       30.6  35.2   2.1      -6.0
# 1889       51.7           9.7       600       32.2  42.3  -2.7      -9.8
# 1925       91.7          53.8       334       52.8  42.7  18.3      -9.8
#
#       penalty  raw_qbr  sack
# 0         1.6     88.3  -3.7
# 1         1.2     83.8  -7.3
# 2         2.7     78.5  -6.1
# 3         2.0     76.1  -6.7
# 4        -0.7     72.6  -7.7
# ...       ...      ...   ...
# 1851      2.3     62.6 -13.0
# 1865      2.2     52.3 -12.7
# 1882      1.4     61.7  -8.2
# 1889      2.6     54.2 -10.0
# 1925      1.6     84.2  -9.8
#
# [927 rows x 14 columns]

# %%
# College_statistics csv
college_statistics_path = Path(r"C:\Users\hsyuk\OneDrive\Desktop\GW Bootcamp\Section 5 - Advanced Topics (18-24)\Project_4\Resources\college_statistics.csv")
college_statistics_df = pd.read_csv(college_statistics_path)
college_statistics_df.head()
# Out:
#    player_id  alt_player_id  player_name pos_abbr   school school_abbr  \
# 0      14420        3915189  Royce Smith       OG  Georgia         UGA
# 1      14420        3915189  Royce Smith       OG  Georgia         UGA
# 2      14420        3915189  Royce Smith       OG  Georgia         UGA
# 3      14420        3915189  Royce Smith       OG  Georgia         UGA
# 4      14420        3915189  Royce Smith       OG  Georgia         UGA
#
#   school_primary_color school_alt_color  season        statistic  value  \
# 0              #CC0000          #000000    2015    Total Tackles   20.0
# 1              #CC0000          #000000    2015     Solo Tackles    9.0
# 2              #CC0000          #000000    2015   Assist Tackles   11.0
# 3              #CC0000          #000000    2015  Passes Defended    0.0
# 4              #CC0000          #000000    2015            Sacks    0.0
#
#    active  all_star
# 0    True     False
# 1    True     False
# 2    True     False
# 3    True     False
# 4    True     False

# %%
# Drop alt_player_id, school_primary_color, school_alt_color columns
columns_to_drop = ['alt_player_id', 'school_primary_color', 'school_alt_color']
college_statistics_df = college_statistics_df.drop(columns=columns_to_drop, axis=1)
college_statistics_df.head()
# Out:
#    player_id  player_name pos_abbr   school school_abbr  season  \
# 0      14420  Royce Smith       OG  Georgia         UGA    2015
# 1      14420  Royce Smith       OG  Georgia         UGA    2015
# 2      14420  Royce Smith       OG  Georgia         UGA    2015
# 3      14420  Royce Smith       OG  Georgia         UGA    2015
# 4      14420  Royce Smith       OG  Georgia         UGA    2015
#
#          statistic  value  active  all_star
# 0    Total Tackles   20.0    True     False
# 1     Solo Tackles    9.0    True     False
# 2   Assist Tackles   11.0    True     False
# 3  Passes Defended    0.0    True     False
# 4            Sacks    0.0    True     False

# %%
college_statistics_df.dropna()
# Out:
#        player_id     player_name pos_abbr   school school_abbr  season  \
# 0          14420     Royce Smith       OG  Georgia         UGA    2015
# 1          14420     Royce Smith       OG  Georgia         UGA    2015
# 2          14420     Royce Smith       OG  Georgia         UGA    2015
# 3          14420     Royce Smith       OG  Georgia         UGA    2015
# 4          14420     Royce Smith       OG  Georgia         UGA    2015
# ...          ...             ...      ...      ...         ...     ...
# 66667     105468  Donovan Stiner        S  Florida         FLA    2020
# 66668     105468  Donovan Stiner        S  Florida         FLA    2020
# 66669     105468  Donovan Stiner        S  Florida         FLA    2020
# 66670     105468  Donovan Stiner        S  Florida         FLA    2020
# 66671     105468  Donovan Stiner        S  Florida         FLA    2020
#
#                      statistic  value  active  all_star
# 0                Total Tackles   20.0    True     False
# 1                 Solo Tackles    9.0    True     False
# 2               Assist Tackles   11.0    True     False
# 3              Passes Defended    0.0    True     False
# 4                        Sacks    0.0    True     False
# ...                        ...    ...     ...       ...
# 66667                    Sacks    0.0    True     False
# 66668           Forced Fumbles    0.0    True     False
# 66669            Interceptions    0.0    True     False
# 66670       Interception Yards    0.0    True     False
# 66671  Interception Touchdowns    0.0    True     False
#
# [58767 rows x 10 columns]

# %%
# ids csv
ids_path = Path(r"C:\Users\hsyuk\OneDrive\Desktop\GW Bootcamp\Section 5 - Advanced Topics (18-24)\Project_4\Resources\ids.csv")
ids_df = pd.read_csv(ids_path)
ids_df
# Out:
#      espn_id         player_name nflfastR_id
# 0      18692          Dan Marino  00-0010379
# 1      19373  Randall Cunningham  00-0003761
# 2      19739       Bubby Brister  00-0001785
# 3      20006    Vinny Testaverde  00-0016193
# 4      20018        Chris Miller  00-0011244
# ..       ...                 ...         ...
# 231   103832        Kyler Murray  00-0035228
# 232   103564     Jarrett Stidham  00-0035264
# 233   103637      Trace McSorley  00-0035146
# 234   103883       Tyree Jackson  00-0024279
# 235   103701        Brett Rypien  00-0034955
#
# [236 rows x 3 columns]

# %%
# Drop Espn_id
ids_df = ids_df.drop(columns = 'espn_id', axis = 1)
ids_df.head()
# Out:
#           player_name nflfastR_id
# 0          Dan Marino  00-0010379
# 1  Randall Cunningham  00-0003761
# 2       Bubby Brister  00-0001785
# 3    Vinny Testaverde  00-0016193
# 4        Chris Miller  00-0011244

# %%
ids_df.dropna()
# Out:
#             player_name nflfastR_id
# 0            Dan Marino  00-0010379
# 1    Randall Cunningham  00-0003761
# 2         Bubby Brister  00-0001785
# 3      Vinny Testaverde  00-0016193
# 4          Chris Miller  00-0011244
# ..                  ...         ...
# 231        Kyler Murray  00-0035228
# 232     Jarrett Stidham  00-0035264
# 233      Trace McSorley  00-0035146
# 234       Tyree Jackson  00-0024279
# 235        Brett Rypien  00-0034955
#
# [236 rows x 2 columns]

# %%
# nfl_draft_profiles csv
nfl_profiles_path = Path(r"C:\Users\hsyuk\OneDrive\Desktop\GW Bootcamp\Section 5 - Advanced Topics (18-24)\Project_4\Resources\nfl_draft_profiles.csv")
nfl_profiles_df = pd.read_csv(nfl_profiles_path)
nfl_profiles_df
# Out:
#        player_id                              guid  alt_player_id  \
# 0          23590                               NaN            NaN
# 1          23591                               NaN            NaN
# 2          23592                               NaN            NaN
# 3          23593                               NaN            NaN
# 4          23594                               NaN            NaN
# ...          ...                               ...            ...
# 12900     105466  841ed58127d19410cc2849ea8f3e1070      3121655.0
# 12901     105467  151d962cf4bf1862bcef120a11880e57      4044431.0
# 12902     105468  d12830501cce353220df8c6bd2b050fc      4240599.0
# 12903     105478  8d1939ce8d84d85651dcff926bebc08b      4369247.0
# 12904     105479  8c7be8c04091e268ae62efde0ba5279b      4035689.0
#
#              player_name       position pos_abbr  weight  height  \
# 0            Bubba Smith  Defensive End       DE       0   0.000
# 1          Clinton Jones   Running Back       RB       0   0.000
# 2         Steve Spurrier    Quarterback       QB       0   0.000
# 3             Bob Griese    Quarterback       QB       0   0.000
# 4         George Webster     Linebacker       LB       0   0.000
# ...                  ...            ...      ...     ...     ...
# 12900        Justus Reed  Defensive End       DE     253  75.000
# 12901      K.J. Costello    Quarterback       QB     227  76.625
# 12902     Donovan Stiner         Safety        S     205  73.500
# 12903     Mac McCain III     Cornerback       CB     186  71.000
# 12904  Josh Imatorbhebhe  Wide Receiver       WR     218  72.875
#
#                                             player_image  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 12900                                                NaN
# 12901                                                NaN
# 12902                                                NaN
# 12903  https://a.espncdn.com/i/headshots/nfldraft/pla...
# 12904  https://a.espncdn.com/i/headshots/nfldraft/pla...
#
#                                                     link  ...  \
# 0      http://insider.espn.com/nfl/draft/player/_/id/...  ...
# 1      http://insider.espn.com/nfl/draft/player/_/id/...  ...
# 2      http://insider.espn.com/nfl/draft/player/_/id/...  ...
# 3      http://insider.espn.com/nfl/draft/player/_/id/...  ...
# 4      http://insider.espn.com/nfl/draft/player/_/id/...  ...
# ...                                                  ...  ...
# 12900  http://insider.espn.com/nfl/draft/player/_/id/...  ...
# 12901  http://insider.espn.com/nfl/draft/player/_/id/...  ...
# 12902  http://insider.espn.com/nfl/draft/player/_/id/...  ...
# 12903  http://insider.espn.com/nfl/draft/player/_/id/...  ...
# 12904  http://insider.espn.com/nfl/draft/player/_/id/...  ...
#
#                    school school_abbr      school_name pos_rk  ovr_rk  grade  \
# 0          Michigan State         MSU         Spartans    NaN     NaN    NaN
# 1          Michigan State         MSU         Spartans    NaN     NaN    NaN
# 2                 Florida         FLA           Gators    NaN     NaN    NaN
# 3                  Purdue         PUR     Boilermakers    NaN     NaN    NaN
# 4          Michigan State         MSU         Spartans    NaN     NaN    NaN
# ...                   ...         ...              ...    ...     ...    ...
# 12900       Virginia Tech          VT           Hokies   31.0   344.0   30.0
# 12901   Mississippi State        MSST         Bulldogs   15.0   345.0   30.0
# 12902             Florida         FLA           Gators   29.0   346.0   30.0
# 12903  North Carolina A&T        NCAT           Aggies   44.0   348.0   30.0
# 12904            Illinois         ILL  Fighting Illini   54.0   349.0   30.0
#
#                                                    text1 text2 text3 text4
# 0                                                    NaN   NaN   NaN   NaN
# 1                                                    NaN   NaN   NaN   NaN
# 2                                                    NaN   NaN   NaN   NaN
# 3                                                    NaN   NaN   NaN   NaN
# 4                                                    NaN   NaN   NaN   NaN
# ...                                                  ...   ...   ...   ...
# 12900                                                NaN   NaN   NaN   NaN
# 12901                                                NaN   NaN   NaN   NaN
# 12902  Stiner is an interchangeable safety with avera...   NaN   NaN   NaN
# 12903                                                NaN   NaN   NaN   NaN
# 12904  Imatorbhebhe is a big target with average spee...   NaN   NaN   NaN
#
# [12905 rows x 21 columns]

# %%
# drop columns
drop_columns = ['alt_player_id','link','school_logo','text1','text2','text3','text4']
nfl_profiles_df=nfl_profiles_df.drop(columns=drop_columns, axis=1)
nfl_profiles_df.head()
# Out:
#    player_id guid     player_name       position pos_abbr  weight  height  \
# 0      23590  NaN     Bubba Smith  Defensive End       DE       0     0.0
# 1      23591  NaN   Clinton Jones   Running Back       RB       0     0.0
# 2      23592  NaN  Steve Spurrier    Quarterback       QB       0     0.0
# 3      23593  NaN      Bob Griese    Quarterback       QB       0     0.0
# 4      23594  NaN  George Webster     Linebacker       LB       0     0.0
#
#   player_image          school school_abbr   school_name  pos_rk  ovr_rk  \
# 0          NaN  Michigan State         MSU      Spartans     NaN     NaN
# 1          NaN  Michigan State         MSU      Spartans     NaN     NaN
# 2          NaN         Florida         FLA        Gators     NaN     NaN
# 3          NaN          Purdue         PUR  Boilermakers     NaN     NaN
# 4          NaN  Michigan State         MSU      Spartans     NaN     NaN
#
#    grade
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
nfl_profiles_df.dropna()
# Out:
#        player_id                              guid        player_name  \
# 11079      51534  031d81566271ea30409f137309621805      Myles Garrett
# 11080      51705  bcf9133c2510f4530f0bc68c1a5d0af7  Mitchell Trubisky
# 11081      51730  9f457077f9400ea835ddc78eadae1518     Solomon Thomas
# 11082      51572  675c1a0988769e80d22f6935d4564e00  Leonard Fournette
# 11083      51674  927ce3ebec0ef60372c8394961ee2f6c        Corey Davis
# ...          ...                               ...                ...
# 12880     104900  abda2d760dc7aec1c02c7fca10871bf9        Milo Eifler
# 12881     105324  deb9b8396f251519727acf91310f3a93          Max Duffy
# 12882     105349  9ac7ee79814969a99e628b7c3267d34d         Zach Smith
# 12903     105478  8d1939ce8d84d85651dcff926bebc08b     Mac McCain III
# 12904     105479  8c7be8c04091e268ae62efde0ba5279b  Josh Imatorbhebhe
#
#                  position pos_abbr  weight  height  \
# 11079       Defensive End       DE     272  76.500
# 11080         Quarterback       QB     222  74.125
# 11081    Defensive Tackle       DT     273  74.625
# 11082        Running Back       RB     240  72.500
# 11083       Wide Receiver       WR     209  74.750
# ...                   ...      ...     ...     ...
# 12880  Outside Linebacker      OLB     228  73.250
# 12881              Punter        P     196  72.750
# 12882         Quarterback       QB     222  75.375
# 12903          Cornerback       CB     186  71.000
# 12904       Wide Receiver       WR     218  72.875
#
#                                             player_image              school  \
# 11079  https://a.espncdn.com/i/headshots/nfldraft/pla...           Texas A&M
# 11080  https://a.espncdn.com/i/headshots/nfldraft/pla...      North Carolina
# 11081  https://a.espncdn.com/i/headshots/nfldraft/pla...            Stanford
# 11082  https://a.espncdn.com/i/headshots/nfldraft/pla...                 LSU
# 11083  https://a.espncdn.com/i/headshots/nfldraft/pla...    Western Michigan
# ...                                                  ...                 ...
# 12880  https://a.espncdn.com/i/headshots/nfldraft/pla...            Illinois
# 12881  https://a.espncdn.com/i/headshots/nfldraft/pla...            Kentucky
# 12882  https://a.espncdn.com/i/headshots/nfldraft/pla...               Tulsa
# 12903  https://a.espncdn.com/i/headshots/nfldraft/pla...  North Carolina A&T
# 12904  https://a.espncdn.com/i/headshots/nfldraft/pla...            Illinois
#
#       school_abbr       school_name  pos_rk  ovr_rk  grade
# 11079        TA&M            Aggies     1.0     1.0   95.0
# 11080         UNC         Tar Heels     1.0    27.0   89.0
# 11081        STAN          Cardinal     1.0     3.0   94.0
# 11082         LSU            Tigers     1.0     4.0   93.0
# 11083         WMU           Broncos     2.0    15.0   91.0
# ...           ...               ...     ...     ...    ...
# 12880         ILL   Fighting Illini    13.0   308.0   31.0
# 12881          UK          Wildcats     3.0   310.0   31.0
# 12882        TLSA  Golden Hurricane    14.0   311.0   31.0
# 12903        NCAT            Aggies    44.0   348.0   30.0
# 12904         ILL   Fighting Illini    54.0   349.0   30.0
#
# [1459 rows x 14 columns]

# %%
# nfl_draft_prospects csv
nfl_prospects_path = Path(r"C:\Users\hsyuk\OneDrive\Desktop\GW Bootcamp\Section 5 - Advanced Topics (18-24)\Project_4\Resources\nfl_draft_prospects.csv")
nfl_prospects_df = pd.read_csv(nfl_prospects_path)
nfl_prospects_df
# Out:
#        draft_year  player_id        player_name       position pos_abbr  \
# 0            1967      23590        Bubba Smith  Defensive End       DE
# 1            1967      23591      Clinton Jones   Running Back       RB
# 2            1967      23592     Steve Spurrier    Quarterback       QB
# 3            1967      23593         Bob Griese    Quarterback       QB
# 4            1967      23594     George Webster     Linebacker       LB
# ...           ...        ...                ...            ...      ...
# 13349        2021     105466        Justus Reed  Defensive End       DE
# 13350        2021     105467      K.J. Costello    Quarterback       QB
# 13351        2021     105468     Donovan Stiner         Safety        S
# 13352        2021     105478     Mac McCain III     Cornerback       CB
# 13353        2021     105479  Josh Imatorbhebhe  Wide Receiver       WR
#
#                    school      school_name school_abbr  \
# 0          Michigan State         Spartans         MSU
# 1          Michigan State         Spartans         MSU
# 2                 Florida           Gators         FLA
# 3                  Purdue     Boilermakers         PUR
# 4          Michigan State         Spartans         MSU
# ...                   ...              ...         ...
# 13349       Virginia Tech           Hokies          VT
# 13350   Mississippi State         Bulldogs        MSST
# 13351             Florida           Gators         FLA
# 13352  North Carolina A&T           Aggies        NCAT
# 13353            Illinois  Fighting Illini         ILL
#
#                                                     link  pick  ...  \
# 0      http://insider.espn.com/nfl/draft/player/_/id/...   1.0  ...
# 1      http://insider.espn.com/nfl/draft/player/_/id/...   2.0  ...
# 2      http://insider.espn.com/nfl/draft/player/_/id/...   3.0  ...
# 3      http://insider.espn.com/nfl/draft/player/_/id/...   4.0  ...
# 4      http://insider.espn.com/nfl/draft/player/_/id/...   5.0  ...
# ...                                                  ...   ...  ...
# 13349  http://insider.espn.com/nfl/draft/player/_/id/...   NaN  ...
# 13350  http://insider.espn.com/nfl/draft/player/_/id/...   NaN  ...
# 13351  http://insider.espn.com/nfl/draft/player/_/id/...   NaN  ...
# 13352  http://insider.espn.com/nfl/draft/player/_/id/...   NaN  ...
# 13353  http://insider.espn.com/nfl/draft/player/_/id/...   NaN  ...
#
#                       team  team_abbr  \
# 0          Baltimore Colts        IND
# 1        Minnesota Vikings        MIN
# 2      San Francisco 49ers         SF
# 3           Miami Dolphins        MIA
# 4           Houston Oilers        TEN
# ...                    ...        ...
# 13349                  NaN        NaN
# 13350                  NaN        NaN
# 13351                  NaN        NaN
# 13352                  NaN        NaN
# 13353                  NaN        NaN
#
#                                           team_logo_espn  \
# 0      https://a.espncdn.com/i/teamlogos/nfl/500/scor...
# 1      https://a.espncdn.com/i/teamlogos/nfl/500/scor...
# 2      https://a.espncdn.com/i/teamlogos/nfl/500/scor...
# 3      https://a.espncdn.com/i/teamlogos/nfl/500/scor...
# 4      https://a.espncdn.com/i/teamlogos/nfl/500/scor...
# ...                                                  ...
# 13349                                                NaN
# 13350                                                NaN
# 13351                                                NaN
# 13352                                                NaN
# 13353                                                NaN
#
#                                    guid weight  height pos_rk ovr_rk  grade  \
# 0                                   NaN    NaN     NaN    NaN    NaN    NaN
# 1                                   NaN    NaN     NaN    NaN    NaN    NaN
# 2                                   NaN    NaN     NaN    NaN    NaN    NaN
# 3                                   NaN    NaN     NaN    NaN    NaN    NaN
# 4                                   NaN    NaN     NaN    NaN    NaN    NaN
# ...                                 ...    ...     ...    ...    ...    ...
# 13349  841ed58127d19410cc2849ea8f3e1070  253.0  75.000   31.0  344.0   30.0
# 13350  151d962cf4bf1862bcef120a11880e57  227.0  76.625   15.0  345.0   30.0
# 13351  d12830501cce353220df8c6bd2b050fc  205.0  73.500   29.0  346.0   30.0
# 13352  8d1939ce8d84d85651dcff926bebc08b  186.0  71.000   44.0  348.0   30.0
# 13353  8c7be8c04091e268ae62efde0ba5279b  218.0  72.875   54.0  349.0   30.0
#
#                                             player_image
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 13349                                                NaN
# 13350                                                NaN
# 13351                                                NaN
# 13352  https://a.espncdn.com/i/headshots/nfldraft/pla...
# 13353  https://a.espncdn.com/i/headshots/nfldraft/pla...
#
# [13354 rows x 24 columns]

# %%
# Drop columns player_image, school_abbr, link, team_logo_espn, team_abbr
columns_drop = ['player_image', 'school_abbr', 'link', 'team_logo_espn', 'team_abbr', 'grade', 'pos_rk', 'ovr_rk']
nfl_prospects_df= nfl_prospects_df.drop(columns = columns_drop, axis=1)
nfl_prospects_df
# Out:
#        draft_year  player_id        player_name       position pos_abbr  \
# 0            1967      23590        Bubba Smith  Defensive End       DE
# 1            1967      23591      Clinton Jones   Running Back       RB
# 2            1967      23592     Steve Spurrier    Quarterback       QB
# 3            1967      23593         Bob Griese    Quarterback       QB
# 4            1967      23594     George Webster     Linebacker       LB
# ...           ...        ...                ...            ...      ...
# 13349        2021     105466        Justus Reed  Defensive End       DE
# 13350        2021     105467      K.J. Costello    Quarterback       QB
# 13351        2021     105468     Donovan Stiner         Safety        S
# 13352        2021     105478     Mac McCain III     Cornerback       CB
# 13353        2021     105479  Josh Imatorbhebhe  Wide Receiver       WR
#
#                    school      school_name  pick  overall  round traded  \
# 0          Michigan State         Spartans   1.0      1.0    1.0  False
# 1          Michigan State         Spartans   2.0      2.0    1.0  False
# 2                 Florida           Gators   3.0      3.0    1.0  False
# 3                  Purdue     Boilermakers   4.0      4.0    1.0  False
# 4          Michigan State         Spartans   5.0      5.0    1.0  False
# ...                   ...              ...   ...      ...    ...    ...
# 13349       Virginia Tech           Hokies   NaN      NaN    NaN    NaN
# 13350   Mississippi State         Bulldogs   NaN      NaN    NaN    NaN
# 13351             Florida           Gators   NaN      NaN    NaN    NaN
# 13352  North Carolina A&T           Aggies   NaN      NaN    NaN    NaN
# 13353            Illinois  Fighting Illini   NaN      NaN    NaN    NaN
#
#              trade_note                 team  \
# 0      from New Orleans      Baltimore Colts
# 1      from N.Y. Giants    Minnesota Vikings
# 2          from Atlanta  San Francisco 49ers
# 3                   NaN       Miami Dolphins
# 4                   NaN       Houston Oilers
# ...                 ...                  ...
# 13349               NaN                  NaN
# 13350               NaN                  NaN
# 13351               NaN                  NaN
# 13352               NaN                  NaN
# 13353               NaN                  NaN
#
#                                    guid  weight  height
# 0                                   NaN     NaN     NaN
# 1                                   NaN     NaN     NaN
# 2                                   NaN     NaN     NaN
# 3                                   NaN     NaN     NaN
# 4                                   NaN     NaN     NaN
# ...                                 ...     ...     ...
# 13349  841ed58127d19410cc2849ea8f3e1070   253.0  75.000
# 13350  151d962cf4bf1862bcef120a11880e57   227.0  76.625
# 13351  d12830501cce353220df8c6bd2b050fc   205.0  73.500
# 13352  8d1939ce8d84d85651dcff926bebc08b   186.0  71.000
# 13353  8c7be8c04091e268ae62efde0ba5279b   218.0  72.875
#
# [13354 rows x 16 columns]

# %%
# Merge 
nfl_merge_df = pd.merge(college_qbr_df, college_statistics_df, on=['player_name'])
# Join ids_df
nfl_merge_df = pd.merge(nfl_merge_df, ids_df, on=['player_name'])
#Join nfl_profiles
nfl_merge_df = pd.merge(nfl_merge_df, nfl_profiles_df, on=['player_name','guid'])
# Join nfl_prospects_df
nfl_merge_df = pd.merge(nfl_merge_df, nfl_prospects_df, on=['player_name','guid'])
nfl_merge_df
# Out:
#       season_x                              guid      player_name   age  \
# 0         2014  37d87523280a9d4a0adb22cfc6d3619c  Patrick Mahomes  25.0
# 1         2014  37d87523280a9d4a0adb22cfc6d3619c  Patrick Mahomes  25.0
# 2         2014  37d87523280a9d4a0adb22cfc6d3619c  Patrick Mahomes  25.0
# 3         2014  37d87523280a9d4a0adb22cfc6d3619c  Patrick Mahomes  25.0
# 4         2014  37d87523280a9d4a0adb22cfc6d3619c  Patrick Mahomes  25.0
# ...        ...                               ...              ...   ...
# 4398      2019  3858bbe06348e3ef5d9f2dd2acb46f44   Tua Tagovailoa  23.0
# 4399      2019  3858bbe06348e3ef5d9f2dd2acb46f44   Tua Tagovailoa  23.0
# 4400      2019  3858bbe06348e3ef5d9f2dd2acb46f44   Tua Tagovailoa  23.0
# 4401      2019  3858bbe06348e3ef5d9f2dd2acb46f44   Tua Tagovailoa  23.0
# 4402      2019  3858bbe06348e3ef5d9f2dd2acb46f44   Tua Tagovailoa  23.0
#
#       total_qbr  points_added  qb_plays  total_epa  pass  run  ...  \
# 0          71.8          10.0       261       18.4  23.7 -0.5  ...
# 1          71.8          10.0       261       18.4  23.7 -0.5  ...
# 2          71.8          10.0       261       18.4  23.7 -0.5  ...
# 3          71.8          10.0       261       18.4  23.7 -0.5  ...
# 4          71.8          10.0       261       18.4  23.7 -0.5  ...
# ...         ...           ...       ...        ...   ...  ...  ...
# 4398       94.8          69.0       302       65.4  68.7 -1.1  ...
# 4399       94.8          69.0       302       65.4  68.7 -1.1  ...
# 4400       94.8          69.0       302       65.4  68.7 -1.1  ...
# 4401       94.8          69.0       302       65.4  68.7 -1.1  ...
# 4402       94.8          69.0       302       65.4  68.7 -1.1  ...
#
#           school  school_name_y  pick  overall  round traded trade_note  \
# 0     Texas Tech    Red Raiders  10.0     10.0    1.0   True   From BUF
# 1     Texas Tech    Red Raiders  10.0     10.0    1.0   True   From BUF
# 2     Texas Tech    Red Raiders  10.0     10.0    1.0   True   From BUF
# 3     Texas Tech    Red Raiders  10.0     10.0    1.0   True   From BUF
# 4     Texas Tech    Red Raiders  10.0     10.0    1.0   True   From BUF
# ...          ...            ...   ...      ...    ...    ...        ...
# 4398     Alabama   Crimson Tide   5.0      5.0    1.0  False        NaN
# 4399     Alabama   Crimson Tide   5.0      5.0    1.0  False        NaN
# 4400     Alabama   Crimson Tide   5.0      5.0    1.0  False        NaN
# 4401     Alabama   Crimson Tide   5.0      5.0    1.0  False        NaN
# 4402     Alabama   Crimson Tide   5.0      5.0    1.0  False        NaN
#
#                     team  weight_y height_y
# 0     Kansas City Chiefs     225.0     74.0
# 1     Kansas City Chiefs     225.0     74.0
# 2     Kansas City Chiefs     225.0     74.0
# 3     Kansas City Chiefs     225.0     74.0
# 4     Kansas City Chiefs     225.0     74.0
# ...                  ...       ...      ...
# 4398      Miami Dolphins     217.0     72.0
# 4399      Miami Dolphins     217.0     72.0
# 4400      Miami Dolphins     217.0     72.0
# 4401      Miami Dolphins     217.0     72.0
# 4402      Miami Dolphins     217.0     72.0
#
# [4403 rows x 50 columns]

# %%
nfl_merge_df.dtypes
# Out:
# season_x           int64
# guid              object
# player_name       object
# age              float64
# total_qbr        float64
# points_added     float64
# qb_plays           int64
# total_epa        float64
# pass             float64
# run              float64
# exp_sack         float64
# penalty          float64
# raw_qbr          float64
# sack             float64
# player_id_x        int64
# pos_abbr_x        object
# school_x          object
# school_abbr_x     object
# season_y           int64
# statistic         object
# value            float64
# active              bool
# all_star            bool
# nflfastR_id       object
# player_id_y        int64
# position_x        object
# pos_abbr_y        object
# weight_x           int64
# height_x         float64
# player_image      object
# school_y          object
# school_abbr_y     object
# school_name_x     object
# pos_rk           float64
# ovr_rk           float64
# grade            float64
# draft_year         int64
# player_id          int64
# position_y        object
# pos_abbr          object
# school            object
# school_name_y     object
# pick             float64
# overall          float64
# round            float64
# traded            object
# trade_note        object
# team              object
# weight_y         float64
# height_y         float64
# dtype: object

# %%
nfl_merge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4403 entries, 0 to 4402
# Data columns (total 50 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   season_x       4403 non-null   int64
#  1   guid           4403 non-null   object
#  2   player_name    4403 non-null   object
#  3   age            2436 non-null   float64
#  4   total_qbr      4403 non-null   float64
#  5   points_added   4403 non-null   float64
#  6   qb_plays       4403 non-null   int64
#  7   total_epa      4403 non-null   float64
#  8   pass           4403 non-null   float64
#  9   run            4403 non-null   float64
#  10  exp_sack       4403 non-null   float64
#  11  penalty        4403 non-null   float64
#  12  raw_qbr        4403 non-null   float64
#  13  sack           4403 non-null   float64
#  14  player_id_x    4403 non-null   int64
#  15  pos_abbr_x     4403 non-null   object
#  16  school_x       4403 non-null   object
#  17  school_abbr_x  4403 non-null   object
#  18  season_y       4403 non-null   int64
#  19  statistic      4403 non-null   object
#  20  value          4403 non-null   float64
#  21  active         4403 non-null   bool
#  22  all_star       4403 non-null   bool
#  23  nflfastR_id    4403 non-null   object
#  24  player_id_y    4403 non-null   int64
#  25  position_x     4403 non-null   object
#  26  pos_abbr_y     4403 non-null   object
#  27  weight_x       4403 non-null   int64
#  28  height_x       4403 non-null   float64
#  29  player_image   4403 non-null   object
#  30  school_y       4403 non-null   object
#  31  school_abbr_y  4403 non-null   object
#  32  school_name_x  4403 non-null   object
#  33  pos_rk         4403 non-null   float64
#  34  ovr_rk         4403 non-null   float64
#  35  grade          4403 non-null   float64
#  36  draft_year     4403 non-null   int64
#  37  player_id      4403 non-null   int64
#  38  position_y     4403 non-null   object
#  39  pos_abbr       4403 non-null   object
#  40  school         4403 non-null   object
#  41  school_name_y  4403 non-null   object
#  42  pick           3617 non-null   float64
#  43  overall        3617 non-null   float64
#  44  round          3617 non-null   float64
#  45  traded         3617 non-null   object
#  46  trade_note     2663 non-null   object
#  47  team           3617 non-null   object
#  48  weight_y       4403 non-null   float64
#  49  height_y       4403 non-null   float64
# dtypes: bool(2), float64(20), int64(8), object(20)
# memory usage: 1.6+ MB

# %%
nfl_merge_df.dropna()
# Out:
#       season_x                              guid      player_name   age  \
# 0         2014  37d87523280a9d4a0adb22cfc6d3619c  Patrick Mahomes  25.0
# 1         2014  37d87523280a9d4a0adb22cfc6d3619c  Patrick Mahomes  25.0
# 2         2014  37d87523280a9d4a0adb22cfc6d3619c  Patrick Mahomes  25.0
# 3         2014  37d87523280a9d4a0adb22cfc6d3619c  Patrick Mahomes  25.0
# 4         2014  37d87523280a9d4a0adb22cfc6d3619c  Patrick Mahomes  25.0
# ...        ...                               ...              ...   ...
# 3261      2017  853f876854bd6a4fcb1063d6df1e7742       Josh Allen  24.0
# 3262      2017  853f876854bd6a4fcb1063d6df1e7742       Josh Allen  24.0
# 3263      2017  853f876854bd6a4fcb1063d6df1e7742       Josh Allen  24.0
# 3264      2017  853f876854bd6a4fcb1063d6df1e7742       Josh Allen  24.0
# 3265      2017  853f876854bd6a4fcb1063d6df1e7742       Josh Allen  24.0
#
#       total_qbr  points_added  qb_plays  total_epa  pass   run  ...  \
# 0          71.8          10.0       261       18.4  23.7  -0.5  ...
# 1          71.8          10.0       261       18.4  23.7  -0.5  ...
# 2          71.8          10.0       261       18.4  23.7  -0.5  ...
# 3          71.8          10.0       261       18.4  23.7  -0.5  ...
# 4          71.8          10.0       261       18.4  23.7  -0.5  ...
# ...         ...           ...       ...        ...   ...   ...  ...
# 3261       60.1          22.1       382       32.5  26.3  17.4  ...
# 3262       60.1          22.1       382       32.5  26.3  17.4  ...
# 3263       60.1          22.1       382       32.5  26.3  17.4  ...
# 3264       60.1          22.1       382       32.5  26.3  17.4  ...
# 3265       60.1          22.1       382       32.5  26.3  17.4  ...
#
#           school  school_name_y  pick  overall  round traded trade_note  \
# 0     Texas Tech    Red Raiders  10.0     10.0    1.0   True   From BUF
# 1     Texas Tech    Red Raiders  10.0     10.0    1.0   True   From BUF
# 2     Texas Tech    Red Raiders  10.0     10.0    1.0   True   From BUF
# 3     Texas Tech    Red Raiders  10.0     10.0    1.0   True   From BUF
# 4     Texas Tech    Red Raiders  10.0     10.0    1.0   True   From BUF
# ...          ...            ...   ...      ...    ...    ...        ...
# 3261     Wyoming        Cowboys   7.0      7.0    1.0   True    From TB
# 3262     Wyoming        Cowboys   7.0      7.0    1.0   True    From TB
# 3263     Wyoming        Cowboys   7.0      7.0    1.0   True    From TB
# 3264     Wyoming        Cowboys   7.0      7.0    1.0   True    From TB
# 3265     Wyoming        Cowboys   7.0      7.0    1.0   True    From TB
#
#                     team  weight_y height_y
# 0     Kansas City Chiefs     225.0     74.0
# 1     Kansas City Chiefs     225.0     74.0
# 2     Kansas City Chiefs     225.0     74.0
# 3     Kansas City Chiefs     225.0     74.0
# 4     Kansas City Chiefs     225.0     74.0
# ...                  ...       ...      ...
# 3261       Buffalo Bills     237.0     77.0
# 3262       Buffalo Bills     237.0     77.0
# 3263       Buffalo Bills     237.0     77.0
# 3264       Buffalo Bills     237.0     77.0
# 3265       Buffalo Bills     237.0     77.0
#
# [1818 rows x 50 columns]
